# %%
import numpy

# %%
arr=numpy.array(['python','java','sql','cloud','github'])
print(arr)
print(type(arr))
# Out:
# ['python' 'java' 'sql' 'cloud' 'github']
# <class 'numpy.ndarray'>

# %%
arr=numpy.array([True,True,False,True,False,False])
print(arr)
# Out:
# [ True  True False  True False False]

# %%
arr=numpy.array(['praffull',9,68.14,True])
print(arr)
# Out:
# ['praffull' '9' '68.14' 'True']

# %% [markdown]
# **Dates**

# %%
# date -> YYYY-MM-DD
arr=numpy.arange('2026-06-09','2026-06-27',dtype='datetime64[D]')
print(arr)
# Out:
# ['2026-06-09' '2026-06-10' '2026-06-11' '2026-06-12' '2026-06-13'
#  '2026-06-14' '2026-06-15' '2026-06-16' '2026-06-17' '2026-06-18'
#  '2026-06-19' '2026-06-20' '2026-06-21' '2026-06-22' '2026-06-23'
#  '2026-06-24' '2026-06-25' '2026-06-26']
