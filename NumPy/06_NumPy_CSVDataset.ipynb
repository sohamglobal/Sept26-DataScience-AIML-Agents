# %%
import numpy

# %%
arr=numpy.genfromtxt("health_fitness_dataset.csv",delimiter=",",dtype=None,encoding=None)
print(arr.shape)
print(arr)
# Out:
# (501, 51)
# [['record_id' 'full_name' 'age' ... 'fasting_glucose_mg_dl'
#   'total_cholesterol_mg_dl' 'hemoglobin_g_dl']
#  ['1' 'Nisha Malhotra' '42' ... '129' '206' '16.8']
#  ['2' 'Geeta Gupta' '21' ... '86' '234' '16.5']
#  ...
#  ['498' 'Bhavna Tiwari' '29' ... '136' '142' '13.3']
#  ['499' 'Usha Shah' '57' ... '123' '141' '12.7']
#  ['500' 'Isha Pandey' '26' ... '108' '207' '12.0']]

# %%
arr=numpy.genfromtxt("https://raw.githubusercontent.com/sohamglobal/datasets/refs/heads/main/ipl_players.csv",delimiter=",",dtype=None,encoding=None)
print(arr.shape)
print(arr)
# Out:
# (51, 9)
# [['name' 'age' 'country' 'player_type' 'price_crore' 'runs' 'wickets'
#   'average' 'strike_rate']
#  ['Virat Kohli' '35' 'India' 'Batter' '21.0' '8004' '4' '53.36' '132.41']
#  ['Rohit Sharma' '37' 'India' 'Batter' '16.0' '6628' '15' '29.86'
#   '128.61']
#  ['Shubman Gill' '24' 'India' 'Batter' '12.5' '3075' '2' '40.46' '148.72']
#  ['KL Rahul' '32' 'India' 'Batter' '14.0' '4683' '2' '45.46' '134.42']
#  ['Faf du Plessis' '39' 'South Africa' 'Batter' '7.0' '3921' '5' '31.86'
#   '134.79']
#  ['David Warner' '37' 'Australia' 'Batter' '5.25' '6397' '3' '41.54'
#   '139.97']
#  ['Jos Buttler' '33' 'England' 'Batter' '14.75' '3582' '1' '43.63'
#   '148.89']
#  ['Ruturaj Gaikwad' '27' 'India' 'Batter' '18.0' '2782' '0' '38.64'
#   '135.62']
#  ['Devdutt Padikkal' '24' 'India' 'Batter' '7.75' '1597' '0' '34.71'
#   '127.15']
#  ['Tilak Varma' '21' 'India' 'Batter' '8.0' '1540' '0' '38.5' '138.58']
#  ['Travis Head' '30' 'Australia' 'Batter' '14.0' '983' '0' '40.96'
# ...
