# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 10.5 MB/s eta 0:00:00
# ...

# %%
import numpy
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://praffull:mongodb913@sharayucluster.fib907c.mongodb.net/?appName=sharayucluster")

# %%
db=client["spiderdb"]
workercoll=db["workers"]

# %%
for doc in workercoll.find():
  print(doc)
# Out:
# {'_id': ObjectId('69a7980668e7db26797c2907'), 'name': 'mitchell santner', 'department': 'admin', 'post': 'manager', 'location': 'kolkata', 'salary': 45000}
# {'_id': ObjectId('69a798db68e7db26797c2908'), 'name': 'glenn phillips', 'department': 'sales', 'post': 'executive', 'mobile': '9765543866'}
# {'_id': ObjectId('69af7e6884b1f0d70e91914e'), 'name': 'pat cummins', 'department': 'marketing', 'post': 'manager', 'location': 'chicago', 'salary': 61200}
# {'_id': ObjectId('69af7eb584b1f0d70e91914f'), 'name': 'dominik szoboszlai', 'department': 'sales', 'post': 'executive', 'location': 'paris', 'salary': 55300}

# %%
cursor=workercoll.find()
docs=list(cursor)
data=[(w['name'],w['department'],w['post']) for w in docs]
print(data)
# Out:
# [('mitchell santner', 'admin', 'manager'), ('glenn phillips', 'sales', 'executive'), ('pat cummins', 'marketing', 'manager'), ('dominik szoboszlai', 'sales', 'executive')]

# %%
arr=numpy.array(data)
print(arr.shape)
print(arr)
# Out:
# (4, 3)
# [['mitchell santner' 'admin' 'manager']
#  ['glenn phillips' 'sales' 'executive']
#  ['pat cummins' 'marketing' 'manager']
#  ['dominik szoboszlai' 'sales' 'executive']]
