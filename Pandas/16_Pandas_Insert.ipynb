# %%
import pandas

# %%
df=pandas.DataFrame(columns=['Name','Python','SQL','MongoDB'])
print(df)
# Out:
# Empty DataFrame
# Columns: [Name, Python, SQL, MongoDB]
# Index: []

# %%
df.loc[0]=['Sharayu',7,9,6]
print(df)
# Out:
#       Name  Python  SQL  MongoDB
# 0  Sharayu       7    9        6

# %%
df.loc[1]=['Aarya',8,9,8]
print(df)
# Out:
#       Name  Python  SQL  MongoDB
# 0  Sharayu       7    9        6
# 1    Aarya       8    9        8

# %%
df.loc[2,['Name',"Python"]]=['Owee',6]
print(df)
# Out:
#       Name  Python  SQL  MongoDB
# 0  Sharayu     7.0  9.0      6.0
# 1    Aarya     8.0  9.0      8.0
# 2     Owee     6.0  NaN      NaN

# %%
df.loc[2,'SQL']=8
print(df)
# Out:
#       Name  Python  SQL  MongoDB
# 0  Sharayu     7.0  9.0      6.0
# 1    Aarya     8.0  9.0      8.0
# 2     Owee     6.0  8.0      NaN

# %%
dic={
    'company':['openai','anthropic','microsoft','google','meta'],
    'aitool':['chatgpt','claude','copilot','gemini','grok']
}
df=pandas.DataFrame(dic)
print(df)
# Out:
#      company   aitool
# 0     openai  chatgpt
# 1  anthropic   claude
# 2  microsoft  copilot
# 3     google   gemini
# 4       meta     grok

# %%
df.insert(2,'usage',['text','code','sports','images','nothing'])
print(df)
# Out:
#      company   aitool    usage
# 0     openai  chatgpt     text
# 1  anthropic   claude     code
# 2  microsoft  copilot   sports
# 3     google   gemini   images
# 4       meta     grok  nothing

# %%
df.insert(0,'code',[x for x in range(521,526)])
print(df)
# Out:
#    code    company   aitool    usage
# 0   521     openai  chatgpt     text
# 1   522  anthropic   claude     code
# 2   523  microsoft  copilot   sports
# 3   524     google   gemini   images
# 4   525       meta     grok  nothing
