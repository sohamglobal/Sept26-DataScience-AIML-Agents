# %%
import pandas

# %%
values={
    'X':[9,26,10,30,1,13],
    'Y':[5,10,15,20,25,30]
}
df=pandas.DataFrame(values)
print(df)
# Out:
#     X   Y
# 0   9   5
# 1  26  10
# 2  10  15
# 3  30  20
# 4   1  25
# 5  13  30

# %%
print(df+3)
# Out:
#     X   Y
# 0  12   8
# 1  29  13
# 2  13  18
# 3  33  23
# 4   4  28
# 5  16  33

# %%
print(df)
# Out:
#     X   Y
# 0   9   5
# 1  26  10
# 2  10  15
# 3  30  20
# 4   1  25
# 5  13  30

# %%
print(df['X']-df['Y'])
# Out:
# 0     4
# 1    16
# 2    -5
# 3    10
# 4   -24
# 5   -17
# dtype: int64

# %%
print(df['X']**2)
# Out:
# 0     81
# 1    676
# 2    100
# 3    900
# 4      1
# 5    169
# Name: X, dtype: int64

# %%
print(df.sum())
# Out:
# X     89
# Y    105
# dtype: int64

# %%
print(df.mean())
# Out:
# X    14.833333
# Y    17.500000
# dtype: float64

# %%
df.describe()
# Out:
#                X          Y
# count   6.000000   6.000000
# mean   14.833333  17.500000
# std    11.016654   9.354143
# min     1.000000   5.000000
# 25%     9.250000  11.250000
# 50%    11.500000  17.500000
# 75%    22.750000  23.750000
# max    30.000000  30.000000

# %%
print(df.count())
# Out:
# X    6
# Y    6
# dtype: int64

# %%
print(df.std())
# Out:
# X    11.016654
# Y     9.354143
# dtype: float64

# %%
print(df.sum(axis=1))
# Out:
# 0    14
# 1    36
# 2    25
# 3    50
# 4    26
# 5    43
# dtype: int64

# %%
import numpy

# %%
print(df.apply(numpy.sqrt))
# Out:
#           X         Y
# 0  3.000000  2.236068
# 1  5.099020  3.162278
# 2  3.162278  3.872983
# 3  5.477226  4.472136
# 4  1.000000  5.000000
# 5  3.605551  5.477226
