# %% [markdown]
# pip install pandas

# %%
import pandas

# %%
s1=pandas.Series([34,56,22,12,76,43,85,62])

# %%
print(s1)
# Out:
# 0    34
# 1    56
# 2    22
# 3    12
# 4    76
# 5    43
# 6    85
# 7    62
# dtype: int64

# %%
print(s1.dtype)
# Out:
# int64

# %%
s2=pandas.Series(['java','python','sql','javascript','mongodb'])

# %%
print(s2)
# Out:
# 0          java
# 1        python
# 2           sql
# 3    javascript
# 4       mongodb
# dtype: object

# %%
s3=pandas.Series(['java','mongodb','claude','azure'],index=['language','database','ai api','cloud'])

# %%
print(s3)
# Out:
# language       java
# database    mongodb
# ai api       claude
# cloud         azure
# dtype: object

# %%
s4=pandas.Series(['sohamglobal',22,95.36,True])

# %%
print(s4)
# Out:
# 0    sohamglobal
# 1             22
# 2          95.36
# 3           True
# dtype: object

# %%
print(s4.dtype)
# Out:
# object
