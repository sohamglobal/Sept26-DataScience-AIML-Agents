# %%
import pandas

# %%
films=[
    ['the matrix','pk','dil se'],
    [1999,2014,1998],
    ['action','comedy','romance'],
    ['english','hindi','tamil'],
    ['keanu reeves','amir khan','shah rukh khan'],
    [8.9,8.7,7.6]
]

# %%
df=pandas.DataFrame(films)
print(df)
# Out:
#               0          1               2
# 0    the matrix         pk          dil se
# 1          1999       2014            1998
# 2        action     comedy         romance
# 3       english      hindi           tamil
# 4  keanu reeves  amir khan  shah rukh khan
# 5           8.9        8.7             7.6

# %%
rows=['filmname','year','genre','language','actor','rating']
cols=['soham','praffull','shailaja']
df=pandas.DataFrame(films,rows,cols)
print(df)
# Out:
#                  soham   praffull        shailaja
# filmname    the matrix         pk          dil se
# year              1999       2014            1998
# genre           action     comedy         romance
# language       english      hindi           tamil
# actor     keanu reeves  amir khan  shah rukh khan
# rating             8.9        8.7             7.6

# %%
print(df['praffull'])
# Out:
# filmname           pk
# year             2014
# genre          comedy
# language        hindi
# actor       amir khan
# rating            8.7
# Name: praffull, dtype: object
