# %%
import pandas

# %%
dataset_url="https://raw.githubusercontent.com/sohamglobal/datasets/refs/heads/main/shopping_behavior.csv"
df=pandas.read_csv(dataset_url)
print(df)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df=pandas.read_csv("https://raw.githubusercontent.com/sohamglobal/datasets/refs/heads/main/cars_dataset_100.csv")
print(df)
# Out:
#         brand         model  launch_year      country body_type  \
# 0      Toyota       Corolla         1966        Japan     Sedan
# 1      Toyota         Camry         1982        Japan     Sedan
# 2      Toyota          RAV4         1994        Japan       SUV
# 3      Toyota  Land Cruiser         1951        Japan       SUV
# 4      Toyota         Supra         1978        Japan     Coupe
# ..        ...           ...          ...          ...       ...
# 95        NIO           ES8         2018        China       SUV
# 96      Haval            H6         2011        China       SUV
# 97  SsangYong        Rexton         2001  South Korea       SUV
# 98       Lada          Niva         1977       Russia       SUV
# 99     Holden     Commodore         1978    Australia     Sedan
#
#           segment  engine_cc  horsepower      fuel_type  transmission  \
# 0         Compact       1798         169  Petrol-Hybrid           CVT
# ...

# %%
df=pandas.read_csv("swiggy_orders.csv")
print(df)
# Out:
#      OrderID      CustomerName  Age  Gender       City  Bill  \
# 0   SWG10001      Aarav Sharma   28    Male     Mumbai   485
# 1   SWG10002       Priya Mehta   34  Female      Delhi   720
# 2   SWG10003       Rohit Verma   22    Male  Bangalore   310
# 3   SWG10004        Sneha Iyer   29  Female    Chennai   890
# 4   SWG10005       Karan Patel   41    Male  Hyderabad  1250
# ..       ...               ...  ...     ...        ...   ...
# 95  SWG10096      Leela Suresh   23  Female    Chennai   290
# 96  SWG10097       Mihir Doshi   35    Male    Kolkata   655
# 97  SWG10098  Nandini Kulkarni   29  Female     Mumbai   905
# 98  SWG10099     Omkar Thakkar   41    Male      Delhi   470
# 99  SWG10100  Preethi Sundaram   27  Female  Bangalore   830
#
#     TimeToDeliver(mins)  Rating
# 0                    32     4.5
# 1                    45     3.8
# 2                    28     4.2
# 3                    55     3.5
# 4                    38     4.7
# ..                  ...     ...
# ...
