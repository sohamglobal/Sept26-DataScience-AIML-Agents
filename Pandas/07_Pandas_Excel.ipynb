# %%
import pandas

# %%
file=pandas.ExcelFile("population.xlsx")
df=file.parse("Sheet2")
print(df)
# Out:
#                                 Country    Region           Subregion  \
# 0                              China[a]      Asia        Eastern Asia
# 1                                 India      Asia       Southern Asia
# 2                         United States  Americas    Northern America
# 3                             Indonesia      Asia  South-eastern Asia
# 4                              Pakistan      Asia       Southern Asia
# ..                                  ...       ...                 ...
# 228         Montserrat (United Kingdom)  Americas           Caribbean
# 229   Falkland Islands (United Kingdom)  Americas       South America
# 230                                Niue   Oceania           Polynesia
# 231               Tokelau (New Zealand)   Oceania           Polynesia
# 232                     Vatican City[z]    Europe     Southern Europe
#
#      Population2018  Population2019  Change
# 0        1427647786      1433783686  0.0043
# ...
