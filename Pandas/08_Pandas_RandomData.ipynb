# %%
import numpy
import pandas

# %%
df=pandas.DataFrame(numpy.random.rand(10,4),columns=['mumbai','chennai','kolkata','new delhi'])
print(df)
# Out:
#      mumbai   chennai   kolkata  new delhi
# 0  0.987329  0.109621  0.354596   0.199494
# 1  0.891337  0.679146  0.478105   0.483672
# 2  0.908735  0.247474  0.293521   0.095978
# 3  0.993684  0.842580  0.148901   0.147167
# 4  0.569005  0.077644  0.960364   0.882843
# 5  0.375452  0.911031  0.106390   0.531839
# 6  0.903452  0.759979  0.593469   0.740660
# 7  0.166259  0.216041  0.249327   0.929269
# 8  0.730762  0.779918  0.019924   0.249113
# 9  0.519445  0.816141  0.512009   0.028086
