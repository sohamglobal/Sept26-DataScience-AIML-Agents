# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 2.6 MB/s eta 0:00:00
# ...

# %%
import pandas
import pymysql

# %%
connection=pymysql.connect(host='mysql-py0726-praffull-py0726.a.aivencloud.com',port=19972,user='avnadmin',password='AVNS_pgl8dVT3nsi5MndPaFY',database='defaultdb')

# %%
df=pandas.read_sql("select * from accounts",connection)
print(df)
# Out:
# /tmp/ipykernel_2248/1281735825.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pandas.read_sql("select * from accounts",connection)
#     accno                   accnm  acctype   balance
# 0    1001                 Sharayu   saving   48870.0
# 1    1002                Praffull    fixed   47530.0
# 2    1004           Mohamed Salah  current  141000.0
# 3    1005             Bukayo Saka    fixed   98750.0
# 4    1006         Kevin De Bruyne      ppf  197680.0
# 5    1007             Cole Palmer   saving   69000.0
# 6    1008             Declan Rice  current  132000.0
# 7    1009         Martin Odegaard    fixed   89250.0
# 8    1010         Virgil van Dijk      ppf  176000.0
# 9    1011  Trent Alexander-Arnold   saving   61570.0
# 10   1012                   Rodri  current  199000.0
# ...

# %%
df.to_pickle("accountsdata")

# %%
connection.close()

# %% [markdown]
# **Start filtering from here**

# %%
df=pandas.read_pickle("accountsdata")
print(df)
# Out:
#     accno                   accnm  acctype   balance
# 0    1001                 Sharayu   saving   48870.0
# 1    1002                Praffull    fixed   47530.0
# 2    1004           Mohamed Salah  current  141000.0
# 3    1005             Bukayo Saka    fixed   98750.0
# 4    1006         Kevin De Bruyne      ppf  197680.0
# 5    1007             Cole Palmer   saving   69000.0
# 6    1008             Declan Rice  current  132000.0
# 7    1009         Martin Odegaard    fixed   89250.0
# 8    1010         Virgil van Dijk      ppf  176000.0
# 9    1011  Trent Alexander-Arnold   saving   61570.0
# 10   1012                   Rodri  current  199000.0
# 11   1013              Phil Foden    fixed  121750.0
# 12   1014         Bruno Fernandes      ppf   88500.0
# 13   1015          Alexander Isak   saving  156250.0
# 14   1016          William Saliba  current   63000.0
# 15   1017         Marcus Rashford    fixed  108500.0
# 16   1018           Ollie Watkins      ppf  143250.0
# ...

# %%
print(df[df['acctype']=='ppf'])
# Out:
#     accno              accnm acctype   balance
# 4    1006    Kevin De Bruyne     ppf  197680.0
# 8    1010    Virgil van Dijk     ppf  176000.0
# 12   1014    Bruno Fernandes     ppf   88500.0
# 16   1018      Ollie Watkins     ppf  143250.0
# 20   1022     Bernardo Silva     ppf   61250.0
# 24   1026  Gabriel Magalhaes     ppf   55500.0
# 28   1030       Bryan Mbeumo     ppf   86250.0
# 32   1034       Jarrod Bowen     ppf  127500.0
# 36   1038     Enzo Fernandez     ppf  118750.0
# 40   1042    Jordan Pickford     ppf  137500.0
# 44   1046       Ismaila Sarr     ppf   59500.0
# 48   1050     Yankuba Minteh     ppf  101250.0

# %%
print(df[df['acctype']!='saving'])
# Out:
#     accno              accnm  acctype   balance
# 1    1002           Praffull    fixed   47530.0
# 2    1004      Mohamed Salah  current  141000.0
# 3    1005        Bukayo Saka    fixed   98750.0
# 4    1006    Kevin De Bruyne      ppf  197680.0
# 6    1008        Declan Rice  current  132000.0
# 7    1009    Martin Odegaard    fixed   89250.0
# 8    1010    Virgil van Dijk      ppf  176000.0
# 10   1012              Rodri  current  199000.0
# 11   1013         Phil Foden    fixed  121750.0
# 12   1014    Bruno Fernandes      ppf   88500.0
# 14   1016     William Saliba  current   63000.0
# 15   1017    Marcus Rashford    fixed  108500.0
# 16   1018      Ollie Watkins      ppf  143250.0
# 18   1020     James Maddison  current   96750.0
# 19   1021      Son Heung-min    fixed  179000.0
# 20   1022     Bernardo Silva      ppf   61250.0
# 22   1024            Ederson  current   92000.0
# 23   1025     Alisson Becker    fixed  168750.0
# 24   1026  Gabriel Magalhaes      ppf   55500.0
# ...

# %%
print(df[(df['acctype']=='ppf') & (df['balance']<100000)])
# Out:
#     accno              accnm acctype  balance
# 12   1014    Bruno Fernandes     ppf  88500.0
# 20   1022     Bernardo Silva     ppf  61250.0
# 24   1026  Gabriel Magalhaes     ppf  55500.0
# 28   1030       Bryan Mbeumo     ppf  86250.0
# 44   1046       Ismaila Sarr     ppf  59500.0

# %%
print(df[(df['acctype']=='ppf') | (df['balance']>150000)])
# Out:
#     accno              accnm  acctype   balance
# 4    1006    Kevin De Bruyne      ppf  197680.0
# 8    1010    Virgil van Dijk      ppf  176000.0
# 10   1012              Rodri  current  199000.0
# 12   1014    Bruno Fernandes      ppf   88500.0
# 13   1015     Alexander Isak   saving  156250.0
# 16   1018      Ollie Watkins      ppf  143250.0
# 19   1021      Son Heung-min    fixed  179000.0
# 20   1022     Bernardo Silva      ppf   61250.0
# 23   1025     Alisson Becker    fixed  168750.0
# 24   1026  Gabriel Magalhaes      ppf   55500.0
# 28   1030       Bryan Mbeumo      ppf   86250.0
# 29   1031        Yoane Wissa   saving  191500.0
# 32   1034       Jarrod Bowen      ppf  127500.0
# 34   1036     Moises Caicedo  current  161000.0
# 36   1038     Enzo Fernandez      ppf  118750.0
# 37   1039          Luis Diaz   saving  152250.0
# 40   1042    Jordan Pickford      ppf  137500.0
# 43   1045         Joao Pedro    fixed  183250.0
# 44   1046       Ismaila Sarr      ppf   59500.0
# ...

# %%
df1=df[(df['acctype']=='ppf') | (df['balance']>150000)]

# %%
print(df1)
# Out:
#     accno              accnm  acctype   balance
# 4    1006    Kevin De Bruyne      ppf  197680.0
# 8    1010    Virgil van Dijk      ppf  176000.0
# 10   1012              Rodri  current  199000.0
# 12   1014    Bruno Fernandes      ppf   88500.0
# 13   1015     Alexander Isak   saving  156250.0
# 16   1018      Ollie Watkins      ppf  143250.0
# 19   1021      Son Heung-min    fixed  179000.0
# 20   1022     Bernardo Silva      ppf   61250.0
# 23   1025     Alisson Becker    fixed  168750.0
# 24   1026  Gabriel Magalhaes      ppf   55500.0
# 28   1030       Bryan Mbeumo      ppf   86250.0
# 29   1031        Yoane Wissa   saving  191500.0
# 32   1034       Jarrod Bowen      ppf  127500.0
# 34   1036     Moises Caicedo  current  161000.0
# 36   1038     Enzo Fernandez      ppf  118750.0
# 37   1039          Luis Diaz   saving  152250.0
# 40   1042    Jordan Pickford      ppf  137500.0
# 43   1045         Joao Pedro    fixed  183250.0
# 44   1046       Ismaila Sarr      ppf   59500.0
# ...
