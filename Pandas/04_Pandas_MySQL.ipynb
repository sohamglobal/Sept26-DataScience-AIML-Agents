# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 1.7 MB/s eta 0:00:00
# ...

# %%
import pandas
import pymysql

# %%
connection=pymysql.connect(
    host='mysql-py0726-praffull-py0726.a.aivencloud.com',
    port=19972,
    user='avnadmin',
    password='AVNS_pgl8dVT3nsi5MndPaFY',
    database='defaultdb')

# %%
df=pandas.read_sql("select * from accounts",connection)
print(df)
# Out:
# /tmp/ipykernel_2038/1281735825.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pandas.read_sql("select * from accounts",connection)
#     accno                   accnm  acctype   balance
# 0    1001                 Sharayu   saving   48870.0
# 1    1002                Praffull    fixed   47530.0
# 2    1003          Erling Haaland   saving  185000.0
# 3    1004           Mohamed Salah  current  142500.0
# 4    1005             Bukayo Saka    fixed   98750.0
# 5    1006         Kevin De Bruyne      ppf  205000.0
# 6    1007             Cole Palmer   saving   67500.0
# 7    1008             Declan Rice  current  132000.0
# 8    1009         Martin Odegaard    fixed   89250.0
# 9    1010         Virgil van Dijk      ppf  176000.0
# 10   1011  Trent Alexander-Arnold   saving   54250.0
# ...

# %%
df=pandas.read_sql("select * from films",connection)
print(df)
# Out:
# /tmp/ipykernel_2038/1146717649.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pandas.read_sql("select * from films",connection)
#     filmid                                           filmname  year  \
# 0        1                           The Shawshank Redemption  1994
# 1        2                                      The Godfather  1972
# 2        3                                    The Dark Knight  2008
# 3        4                              The Godfather Part II  1974
# 4        5                                       12 Angry Men  1957
# 5        6      The Lord of the Rings: The Return of the King  2003
# 6        7                                       Pulp Fiction  1994
# 7        8                                   Schindler's List  1993
# 8        9                                          Inception  2010
# ...

# %%
df_players=pandas.read_sql("select * from players",connection)
print(df_players)
# Out:
# /tmp/ipykernel_2038/391614389.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_players=pandas.read_sql("select * from players",connection)
#     playerid           playername     sport       country
# 0          3          Steve Smith   Cricket     Australia
# 1          4          Pat Cummins   Cricket     Australia
# 2          5          Travis Head   Cricket     Australia
# 3          6       Mitchell Starc   Cricket     Australia
# 4          7   Marnus Labuschagne   Cricket     Australia
# 5          8             Joe Root   Cricket       England
# 6          9           Ben Stokes   Cricket       England
# 7         10          Harry Brook   Cricket       England
# 8         11         Jofra Archer   Cricket       England
# 9         12      Kane Williamson   Cricket   New Zealand
# ...

# %%
connection.close()

# %%
print(df_players)
# Out:
#     playerid           playername     sport       country
# 0          3          Steve Smith   Cricket     Australia
# 1          4          Pat Cummins   Cricket     Australia
# 2          5          Travis Head   Cricket     Australia
# 3          6       Mitchell Starc   Cricket     Australia
# 4          7   Marnus Labuschagne   Cricket     Australia
# 5          8             Joe Root   Cricket       England
# 6          9           Ben Stokes   Cricket       England
# 7         10          Harry Brook   Cricket       England
# 8         11         Jofra Archer   Cricket       England
# 9         12      Kane Williamson   Cricket   New Zealand
# 10        13      Rachin Ravindra   Cricket   New Zealand
# 11        14           Babar Azam   Cricket      Pakistan
# 12        15  Shaheen Shah Afridi   Cricket      Pakistan
# 13        16        Kagiso Rabada   Cricket  South Africa
# 14        17     Heinrich Klaasen   Cricket  South Africa
# ...
