# %%
import pandas

# %%
url="https://raw.githubusercontent.com/sohamglobal/datasets/refs/heads/main/PlayersPL2026.csv"

# %%
df=pandas.read_csv(url)
print(df)
# Out:
#             player_name  age               club    position  jersey_number  \
# 0            David Raya   31            Arsenal  Goalkeeper            1.0
# 1     Kepa Arrizabalaga   31            Arsenal  Goalkeeper           13.0
# 2         Illan Meslier   26            Arsenal  Goalkeeper           30.0
# 3        William Saliba   25            Arsenal    Defender            2.0
# 4    Cristhian Mosquera   22            Arsenal    Defender            3.0
# ..                  ...  ...                ...         ...            ...
# 581          Mathys Tel   21  Tottenham Hotspur     Forward           11.0
# 582     Dominic Solanke   29  Tottenham Hotspur     Forward           19.0
# 583       Omar Marmoush   27  Tottenham Hotspur     Forward           22.0
# 584     Mykhailo Mudryk   25  Tottenham Hotspur     Forward           27.0
# 585      Wilson Odobert   21  Tottenham Hotspur     Forward           28.0
#
#      country
# 0      Spain
# 1      Spain
# 2     France
# ...

# %%
print(df.isnull().sum())
# Out:
# player_name      0
# age              0
# club             0
# position         0
# jersey_number    1
# country          0
# dtype: int64

# %%
df=df.dropna(subset=['jersey_number'])

# %%
df['jersey_number']=df['jersey_number'].astype(int)

# %%
print(df)
# Out:
#             player_name  age               club    position  jersey_number  \
# 0            David Raya   31            Arsenal  Goalkeeper              1
# 1     Kepa Arrizabalaga   31            Arsenal  Goalkeeper             13
# 2         Illan Meslier   26            Arsenal  Goalkeeper             30
# 3        William Saliba   25            Arsenal    Defender              2
# 4    Cristhian Mosquera   22            Arsenal    Defender              3
# ..                  ...  ...                ...         ...            ...
# 581          Mathys Tel   21  Tottenham Hotspur     Forward             11
# 582     Dominic Solanke   29  Tottenham Hotspur     Forward             19
# 583       Omar Marmoush   27  Tottenham Hotspur     Forward             22
# 584     Mykhailo Mudryk   25  Tottenham Hotspur     Forward             27
# 585      Wilson Odobert   21  Tottenham Hotspur     Forward             28
#
#      country
# 0      Spain
# 1      Spain
# 2     France
# ...

# %%
print(df['player_name'])
# Out:
# 0              David Raya
# 1       Kepa Arrizabalaga
# 2           Illan Meslier
# 3          William Saliba
# 4      Cristhian Mosquera
#               ...
# 581            Mathys Tel
# 582       Dominic Solanke
# 583         Omar Marmoush
# 584       Mykhailo Mudryk
# 585        Wilson Odobert
# Name: player_name, Length: 585, dtype: object

# %%
print(df['player_name'].head(3))
# Out:
# 0           David Raya
# 1    Kepa Arrizabalaga
# 2        Illan Meslier
# Name: player_name, dtype: object

# %%
print(df[['player_name','country']])
# Out:
#             player_name  country
# 0            David Raya    Spain
# 1     Kepa Arrizabalaga    Spain
# 2         Illan Meslier   France
# 3        William Saliba   France
# 4    Cristhian Mosquera    Spain
# ..                  ...      ...
# 581          Mathys Tel   France
# 582     Dominic Solanke  England
# 583       Omar Marmoush    Egypt
# 584     Mykhailo Mudryk  Ukraine
# 585      Wilson Odobert   France
#
# [585 rows x 2 columns]

# %%
print(df.loc[15])
# Out:
# player_name      Martín Zubimendi
# age                            27
# club                      Arsenal
# position               Midfielder
# jersey_number                  36
# country                     Spain
# Name: 15, dtype: object

# %%
print(df.loc[5:9])
# Out:
#          player_name  age     club  position  jersey_number      country
# 5          Ben White   28  Arsenal  Defender              4      England
# 6     Piero Hincapié   24  Arsenal  Defender              5      Ecuador
# 7  Gabriel Magalhães   28  Arsenal  Defender              6       Brazil
# 8     Jurriën Timber   25  Arsenal  Defender             12  Netherlands
# 9         Ezri Konsa   28  Arsenal  Defender             15      England

# %%
print(df.loc[24,'player_name'])
# Out:
# Kai Havertz

# %%
print(df.loc[25:32,['player_name','club']])
# Out:
#           player_name         club
# 25         Max Dowman      Arsenal
# 26  Emiliano Martínez  Aston Villa
# 27          Joe Gauci  Aston Villa
# 28        Zion Suzuki  Aston Villa
# 29        Marco Bizot  Aston Villa
# 30       Oliwier Zych  Aston Villa
# 31         Matty Cash  Aston Villa
# 32    Victor Lindelöf  Aston Villa

# %%
print(df.sort_values('age'))
# Out:
#            player_name  age                    club    position  \
# 25          Max Dowman   16                 Arsenal     Forward
# 438        Floyd Samba   17         Manchester City  Midfielder
# 434     Ayyoub Bouaddi   18         Manchester City  Midfielder
# 491         Sean Steur   18        Newcastle United  Midfielder
# 425  Kaden Braithwaite   18         Manchester City    Defender
# ..                 ...  ...                     ...         ...
# 528        Simon Moore   36              Sunderland  Goalkeeper
# 115       Jason Steele   36  Brighton & Hove Albion  Goalkeeper
# 560    Martin Dúbravka   37       Tottenham Hotspur  Goalkeeper
# 58      Fraser Forster   38         AFC Bournemouth  Goalkeeper
# 447         Tom Heaton   40       Manchester United  Goalkeeper
#
#      jersey_number      country
# 25              56      England
# 438             75      England
# 434             32       France
# 491             14  Netherlands
# ...
