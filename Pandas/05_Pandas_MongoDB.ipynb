# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.18.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting dnspython<3.0.0,>=2.7.0 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.18.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.6 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 16.1 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.18.1

# %%
import pandas
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://praffull:mongodb913@sharayucluster.dpfu46o.mongodb.net/?appName=SharayuCluster")

# %%
db=client["spiderdb"]
coll=db["coworkers"]

# %%
data=list(coll.find())
print(data)
# Out:
# [{'_id': ObjectId('6a44846b77f8c56ee9654943'), 'name': 'Amit Sharma', 'gender': 'Male', 'age': 28, 'department': 'IT', 'post': 'Software Developer', 'location': 'Pune', 'salary': 65000}, {'_id': ObjectId('6a44846b77f8c56ee9654944'), 'name': 'Priya Deshmukh', 'gender': 'Female', 'age': 31, 'department': 'HR', 'post': 'HR Manager', 'location': 'Mumbai', 'salary': 72000}, {'_id': ObjectId('6a44846b77f8c56ee9654945'), 'name': 'Rahul Verma', 'gender': 'Male', 'age': 35, 'department': 'Finance', 'post': 'Accountant', 'location': 'Nagpur', 'salary': 68000}, {'_id': ObjectId('6a44846b77f8c56ee9654946'), 'name': 'Sneha Kulkarni', 'gender': 'Female', 'age': 27, 'department': 'Marketing', 'post': 'Marketing Executive', 'location': 'Hyderabad', 'salary': 58000}, {'_id': ObjectId('6a44846b77f8c56ee9654947'), 'name': 'Vikram Patil', 'gender': 'Male', 'age': 40, 'department': 'Sales', 'post': 'Sales Manager', 'location': 'Bengaluru', 'salary': 90000}, {'_id': ObjectId('6a44846b77f8c56ee9654948'), 'name': 'Neha Joshi', 'gender': 'Female', 'age': 29, 'department': 'IT', 'post': 'System Analyst', 'location': 'Nagpur', 'salary': 76000}, {'_id': ObjectId('6a44846b77f8c56ee9654949'), 'name': 'Arjun Mehta', 'gender': 'Male', 'age': 33, 'department': 'Operations', 'post': 'Operations Manager', 'location': 'Chennai', 'salary': 85000}, {'_id': ObjectId('6a44846b77f8c56ee965494a'), 'name': 'Pooja Singh', 'gender': 'Female', 'age': 26, 'department': 'Support', 'post': 'Customer Support Executive', 'location': 'Pune', 'salary': 45000}, {'_id': ObjectId('6a44846b77f8c56ee965494b'), 'name': 'Rohit Gupta', 'gender': 'Male', 'age': 30, 'department': 'IT', 'post': 'Database Administrator', 'location': 'Mumbai', 'salary': 80000}, {'_id': ObjectId('6a44846b77f8c56ee965494c'), 'name': 'Anjali Nair', 'gender': 'Female', 'age': 32, 'department': 'Research', 'post': 'Data Scientist', 'location': 'Kochi', 'salary': 98000}, {'_id': ObjectId('6a44846b77f8c56ee965494e'), 'name': 'Meera Iyer', 'gender': 'Female', 'age': 24, 'department': 'Design', 'post': 'UI Designer', 'location': 'Bengaluru', 'salary': 62000}, {'_id': ObjectId('6a44846b77f8c56ee965494f'), 'name': 'Sandeep Yadav', 'gender': 'Male', 'age': 41, 'department': 'Administration', 'post': 'Office Manager', 'location': 'Indore', 'salary': 70000}, {'_id': ObjectId('6a44846b77f8c56ee9654950'), 'name': 'Kavita Rao', 'gender': 'Female', 'age': 34, 'department': 'Quality Assurance', 'post': 'QA Lead', 'location': 'Pune', 'salary': 93500.0}, {'_id': ObjectId('6a44846b77f8c56ee9654951'), 'name': 'Nitin Choudhary', 'gender': 'Male', 'age': 29, 'department': 'Cyber Security', 'post': 'Security Engineer', 'location': 'Hyderabad', 'salary': 95000}]

# %%
df=pandas.DataFrame(data)
print(df)
# Out:
#                          _id             name  gender  age         department  \
# 0   6a44846b77f8c56ee9654943      Amit Sharma    Male   28                 IT
# 1   6a44846b77f8c56ee9654944   Priya Deshmukh  Female   31                 HR
# 2   6a44846b77f8c56ee9654945      Rahul Verma    Male   35            Finance
# 3   6a44846b77f8c56ee9654946   Sneha Kulkarni  Female   27          Marketing
# 4   6a44846b77f8c56ee9654947     Vikram Patil    Male   40              Sales
# 5   6a44846b77f8c56ee9654948       Neha Joshi  Female   29                 IT
# 6   6a44846b77f8c56ee9654949      Arjun Mehta    Male   33         Operations
# 7   6a44846b77f8c56ee965494a      Pooja Singh  Female   26            Support
# 8   6a44846b77f8c56ee965494b      Rohit Gupta    Male   30                 IT
# 9   6a44846b77f8c56ee965494c      Anjali Nair  Female   32           Research
# 10  6a44846b77f8c56ee965494e       Meera Iyer  Female   24             Design
# 11  6a44846b77f8c56ee965494f    Sandeep Yadav    Male   41     Administration
# 12  6a44846b77f8c56ee9654950       Kavita Rao  Female   34  Quality Assurance
# 13  6a44846b77f8c56ee9654951  Nitin Choudhary    Male   29     Cyber Security
#
#                           post   location   salary
# 0           Software Developer       Pune  65000.0
# 1                   HR Manager     Mumbai  72000.0
# 2                   Accountant     Nagpur  68000.0
# 3          Marketing Executive  Hyderabad  58000.0
# 4                Sales Manager  Bengaluru  90000.0
# 5               System Analyst     Nagpur  76000.0
# 6           Operations Manager    Chennai  85000.0
# 7   Customer Support Executive       Pune  45000.0
# 8       Database Administrator     Mumbai  80000.0
# 9               Data Scientist      Kochi  98000.0
# 10                 UI Designer  Bengaluru  62000.0
# 11              Office Manager     Indore  70000.0
# 12                     QA Lead       Pune  93500.0
# 13           Security Engineer  Hyderabad  95000.0

# %%
coll=db["films"]
data=list(coll.find())
print(data)
# Out:
# [{'_id': ObjectId('6a4725e559b8e7b650081490'), 'filmname': 'The Shawshank Redemption', 'releaseyear': 1994, 'genre': 'Drama', 'language': 'English', 'director': 'Frank Darabont', 'imdbrating': 9.3}, {'_id': ObjectId('6a4725e559b8e7b650081491'), 'filmname': 'The Godfather', 'releaseyear': 1972, 'genre': 'Crime, Drama', 'language': 'English', 'director': 'Francis Ford Coppola', 'imdbrating': 9.2}, {'_id': ObjectId('6a4725e559b8e7b650081492'), 'filmname': 'The Dark Knight', 'releaseyear': 2008, 'genre': 'Action, Crime, Drama', 'language': 'English', 'director': 'Christopher Nolan', 'imdbrating': 9.1}, {'_id': ObjectId('6a4725e559b8e7b650081493'), 'filmname': 'The Godfather Part II', 'releaseyear': 1974, 'genre': 'Crime, Drama', 'language': 'English', 'director': 'Francis Ford Coppola', 'imdbrating': 9}, {'_id': ObjectId('6a4725e559b8e7b650081494'), 'filmname': '12 Angry Men', 'releaseyear': 1957, 'genre': 'Drama', 'language': 'English', 'director': 'Sidney Lumet', 'imdbrating': 9}, {'_id': ObjectId('6a4725e559b8e7b650081495'), 'filmname': 'The Lord of the Rings: The Return of the King', 'releaseyear': 2003, 'genre': 'Adventure, Drama, Fantasy', 'language': 'English', 'director': 'Peter Jackson', 'imdbrating': 9}, {'_id': ObjectId('6a4725e559b8e7b650081496'), 'filmname': "Schindler's List", 'releaseyear': 1993, 'genre': 'Biography, Drama, History', 'language': 'English', 'director': 'Steven Spielberg', 'imdbrating': 9}, {'_id': ObjectId('6a4725e559b8e7b650081497'), 'filmname': 'The Lord of the Rings: The Fellowship of the Ring', 'releaseyear': 2001, 'genre': 'Adventure, Drama, Fantasy', 'language': 'English', 'director': 'Peter Jackson', 'imdbrating': 8.9}, {'_id': ObjectId('6a4725e559b8e7b650081498'), 'filmname': 'Pulp Fiction', 'releaseyear': 1994, 'genre': 'Crime, Drama', 'language': 'English', 'director': 'Quentin Tarantino', 'imdbrating': 8.8}, {'_id': ObjectId('6a4725e559b8e7b650081499'), 'filmname': 'The Good, the Bad and the Ugly', 'releaseyear': 1966, 'genre': 'Western', 'language': 'Italian', 'director': 'Sergio Leone', 'imdbrating': 8.8}, {'_id': ObjectId('6a4725e559b8e7b65008149a'), 'filmname': 'The Lord of the Rings: The Two Towers', 'releaseyear': 2002, 'genre': 'Adventure, Drama, Fantasy', 'language': 'English', 'director': 'Peter Jackson', 'imdbrating': 8.8}, {'_id': ObjectId('6a4725e559b8e7b65008149b'), 'filmname': 'Forrest Gump', 'releaseyear': 1994, 'genre': 'Drama, Romance', 'language': 'English', 'director': 'Robert Zemeckis', 'imdbrating': 8.8}, {'_id': ObjectId('6a4725e559b8e7b65008149c'), 'filmname': 'Fight Club', 'releaseyear': 1999, 'genre': 'Drama', 'language': 'English', 'director': 'David Fincher', 'imdbrating': 8.8}, {'_id': ObjectId('6a4725e559b8e7b65008149d'), 'filmname': 'Inception', 'releaseyear': 2010, 'genre': 'Action, Adventure, Sci-Fi', 'language': 'English', 'director': 'Christopher Nolan', 'imdbrating': 8.8}, {'_id': ObjectId('6a4725e659b8e7b65008149e'), 'filmname': 'Star Wars: Episode V - The Empire Strikes Back', 'releaseyear': 1980, 'genre': 'Action, Adventure, Fantasy', 'language': 'English', 'director': 'Irvin Kershner', 'imdbrating': 8.7}]

# %%
df=pandas.DataFrame(data)
print(df)
# Out:
#                          _id  \
# 0   6a4725e559b8e7b650081490
# 1   6a4725e559b8e7b650081491
# 2   6a4725e559b8e7b650081492
# 3   6a4725e559b8e7b650081493
# 4   6a4725e559b8e7b650081494
# 5   6a4725e559b8e7b650081495
# 6   6a4725e559b8e7b650081496
# 7   6a4725e559b8e7b650081497
# 8   6a4725e559b8e7b650081498
# 9   6a4725e559b8e7b650081499
# 10  6a4725e559b8e7b65008149a
# 11  6a4725e559b8e7b65008149b
# 12  6a4725e559b8e7b65008149c
# 13  6a4725e559b8e7b65008149d
# 14  6a4725e659b8e7b65008149e
#
#                                              filmname  releaseyear  \
# 0                            The Shawshank Redemption         1994
# 1                                       The Godfather         1972
# 2                                     The Dark Knight         2008
# 3                               The Godfather Part II         1974
# 4                                        12 Angry Men         1957
# 5       The Lord of the Rings: The Return of the King         2003
# 6                                    Schindler's List         1993
# 7   The Lord of the Rings: The Fellowship of the Ring         2001
# 8                                        Pulp Fiction         1994
# 9                      The Good, the Bad and the Ugly         1966
# 10              The Lord of the Rings: The Two Towers         2002
# 11                                       Forrest Gump         1994
# 12                                         Fight Club         1999
# 13                                          Inception         2010
# 14     Star Wars: Episode V - The Empire Strikes Back         1980
#
#                          genre language              director  imdbrating
# 0                        Drama  English        Frank Darabont         9.3
# 1                 Crime, Drama  English  Francis Ford Coppola         9.2
# 2         Action, Crime, Drama  English     Christopher Nolan         9.1
# 3                 Crime, Drama  English  Francis Ford Coppola         9.0
# 4                        Drama  English          Sidney Lumet         9.0
# 5    Adventure, Drama, Fantasy  English         Peter Jackson         9.0
# 6    Biography, Drama, History  English      Steven Spielberg         9.0
# 7    Adventure, Drama, Fantasy  English         Peter Jackson         8.9
# 8                 Crime, Drama  English     Quentin Tarantino         8.8
# 9                      Western  Italian          Sergio Leone         8.8
# 10   Adventure, Drama, Fantasy  English         Peter Jackson         8.8
# 11              Drama, Romance  English       Robert Zemeckis         8.8
# 12                       Drama  English         David Fincher         8.8
# 13   Action, Adventure, Sci-Fi  English     Christopher Nolan         8.8
# 14  Action, Adventure, Fantasy  English        Irvin Kershner         8.7
